# %%
# !pip install TextLoader
# !pip install langchain_community

# %%
from langchain_community.document_loaders import DirectoryLoader, PyPDFLoader
# Out:
# /tmp/ipykernel_47084/1535229276.py:1: DeprecationWarning: `langchain-community` is being sunset and is no longer actively maintained. See https://github.com/langchain-ai/langchain-community/issues/674 for details and migration guidance toward standalone integration packages.
#   from langchain_community.document_loaders import DirectoryLoader, PyPDFLoader

# %%
# !pip install pypdf

# %%
from langchain_community.document_loaders import PyPDFLoader

loader = PyPDFLoader("./administrator739c7aa745c5afab5decf2e100caf1c5.pdf")
docs = loader.load()

# %%
print(len(docs))
# Out:
# 50

# %%
print(docs[0].page_content)
print(docs[0].metadata)
# Out:
# Page 1 of 50
# Updated till 04.08.2023
#
#
#
#
#
# THE CONTROL OF NARCOTIC SUBSTANCES ACT,
# 1997
#
# CONTENTS
#
# CHAPTER I
# PRELIMINARY
#
# 1. Short title and commencement.
# 2. Definitions.
# 3. Calculation of percentages in liquid preparations.
#
#
# CHAPTER II
# PROHIBITION AND PUNISHMENT
#
# 4. Prohibition of cultivation of narcotic plants.
# 5. Punishment for contravention of section 4.
# 6. Prohibition of possession of narcotic drugs, etc.
# 7. Prohibition of import or export of narcotic drugs, etc.
# 8. Prohibition on trafficking or financing the trafficking of narcotic drugs etc.
# 9. Punishment for contravention of sections 6, 7 and 8.
# 10. Prohibition on owning, operating premises or machinery for manufacture of narcotic drugs,
# etc.
# 11. Punishment for contravention of section 10.
# 12. Prohibition of acquisition and possession of assets derived from narcotic offences.
# 13. Punishment for contravention of section 12.
# ...

# %%
print(len(docs))
print(type(docs))
print(type(docs[0]))
# Out:
# 50
# <class 'list'>
# <class 'langchain_core.documents.base.Document'>

# %%
d = loader.load()
for dd in d:
  print(dd.metadata)

print(len(d))
# Out:
# {'producer': 'Microsoft® Word 2016', 'creator': 'Microsoft® Word 2016', 'creationdate': '2023-08-07T14:19:46+05:00', 'title': 'NATIONAL TARIFF COMMISSION ACT, 1950', 'author': 'LOPC PCT', 'moddate': '2023-08-07T14:19:46+05:00', 'source': './administrator739c7aa745c5afab5decf2e100caf1c5.pdf', 'total_pages': 50, 'page': 0, 'page_label': '1'}
# {'producer': 'Microsoft® Word 2016', 'creator': 'Microsoft® Word 2016', 'creationdate': '2023-08-07T14:19:46+05:00', 'title': 'NATIONAL TARIFF COMMISSION ACT, 1950', 'author': 'LOPC PCT', 'moddate': '2023-08-07T14:19:46+05:00', 'source': './administrator739c7aa745c5afab5decf2e100caf1c5.pdf', 'total_pages': 50, 'page': 1, 'page_label': '2'}
# ...

# %%
'''docs = loader.load()

splitter = CharacterTextSplitter(
    chunk_size=200,
    chunk_overlap=0,
    length_function=len
)'''
# Out:
# 'docs = loader.load()\n\nsplitter = CharacterTextSplitter(\n    chunk_size=200,\n    chunk_overlap=0,\n    length_function=len\n)'

# %%
from langchain_text_splitters import RecursiveCharacterTextSplitter
text_splitter = RecursiveCharacterTextSplitter(
    chunk_size=200,
    chunk_overlap=0,
    length_function=len
)

# %%
#chunks = text_splitter.split_documents(combined_documents)

# %%
'''text_splitter = RecursiveCharacterTextSplitter(
    chunk_size=300,
    chunk_overlap=30,
    separators=[
        "\n\n",
        "\n",
        ". ",
        " ",
        ""
    ]
)
'''
# Out:
# 'text_splitter = RecursiveCharacterTextSplitter(\n    chunk_size=300,\n    chunk_overlap=30,\n    separators=[\n        "\n\n",\n        "\n",\n        ". ",\n        " ",\n        ""\n    ]\n)\n'

# %%
chunks = text_splitter.split_documents(d)

# %%
print(chunks[0].page_content)
print(chunks[0].metadata)
# Out:
# Page 1 of 50
# Updated till 04.08.2023
#
#
#
#
#
# THE CONTROL OF NARCOTIC SUBSTANCES ACT,
# 1997
#
# CONTENTS
#
# CHAPTER I
# PRELIMINARY
#
# 1. Short title and commencement.
# 2. Definitions.
# {'producer': 'Microsoft® Word 2016', 'creator': 'Microsoft® Word 2016', 'creationdate': '2023-08-07T14:19:46+05:00', 'title': 'NATIONAL TARIFF COMMISSION ACT, 1950', 'author': 'LOPC PCT', 'moddate': '2023-08-07T14:19:46+05:00', 'source': './administrator739c7aa745c5afab5decf2e100caf1c5.pdf', 'total_pages': 50, 'page': 0, 'page_label': '1'}

# %%
print(len(chunks))
# Out:
# 754

# %%
# !pip install -U sentence-transformers langchain-huggingface

# %%
from langchain_huggingface import HuggingFaceEmbeddings

# %%
embeddings = HuggingFaceEmbeddings(
    model_name="sentence-transformers/all-MiniLM-L6-v2"
)
# Out:
# ...
# WARNING:huggingface_hub.utils._http:Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# Loading weights:   0%|          | 0/103 [00:00<?, ?it/s]

# %%
vectors = embeddings.embed_documents([doc.page_content for doc in d])

# %%
chunk_texts = [chunk.page_content for chunk in d]

vectors = embeddings.embed_documents(chunk_texts)

# %%
print("Number of chunks:", len(chunks))
print("Number of vectors:", len(vectors))
# Out:
# Number of chunks: 754
# Number of vectors: 50

# %%
print(vectors[0])
# Out:
# [0.01444938126951456, 0.038457661867141724, -0.028033077716827393, -0.04484465345740318, 0.02489866502583027, 0.09111711382865906, 0.0272505022585392, 0.02051377296447754, -0.09553766995668411, 0.0425831638276577, 0.03796469792723656, 0.04292217642068863, 0.07401513308286667, 0.10549309849739075, -0.006610597483813763, -0.016049817204475403, 0.01988029293715954, -0.0010631972691044211, -0.010942275635898113, 0.06411836296319962, 0.12978097796440125, 0.058638717979192734, 0.10461962223052979, 0.04614527150988579, -0.05165879800915718, -0.010869640856981277, -0.02825499325990677, -0.017087576910853386, -0.045956872403621674, 0.03122025541961193, -0.09038326889276505, 0.06343839317560196, -0.06008011847734451, 0.04158031940460205, 0.006005601957440376, -0.13075727224349976, 0.00945302750915289, -0.02452627196907997, 0.0937521681189537, 0.007025349885225296, 0.0360833965241909, -0.07454762607812881, -0.07961127161979675, 0.10040217638015747, -0.03883039578795433, -0.03305257484316826, -0
# ...

# %%
print(len(vectors[0]))
# Out:
# 384

# %%
# !pip install chromadb

# %%
from langchain_community.vectorstores import Chroma

# %%
from langchain_core.documents import Document

# %%
vector_store = Chroma(
    collection_name="sample",
    embedding_function=embeddings,
    persist_directory = "chroma_db"
)
# Out:
# /tmp/ipykernel_47084/503240271.py:1: LangChainDeprecationWarning: The class `Chroma` was deprecated in LangChain 0.2.9 and will be removed in 1.0. An updated version of the class exists in the `langchain-chroma package and should be used instead. To use it run `pip install -U `langchain-chroma` and import as `from `langchain_chroma import Chroma``.
#   vector_store = Chroma(

# %%
print(vector_store)

# %%
print('Number of stored chunks: ', vector_store._collection.count())
# Out:
# Number of stored chunks:  50

# %%
# !pip install -U langchain langchain-community langchain-core rank_bm25
# !pip install -U langchain-classic rank_bm25

# %%
from langchain_community.retrievers import BM25Retriever
from langchain_classic.retrievers import EnsembleRetriever

# Vector retriever
vector_retriever = vector_store.as_retriever(
    search_type="similarity",
    search_kwargs={
        "k": 3
    }
)

# Keyword retriever
bm25_retriever = BM25Retriever.from_documents(docs)
bm25_retriever.k = 3

# Hybrid retriever
retriever = EnsembleRetriever(
    retrievers=[vector_retriever, bm25_retriever],
    weights=[0.5, 0.5]
)

# %%
# !pip install -U langchain-openai
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 125.8/125.8 kB 5.0 MB/s eta 0:00:00
# ...

# %%
from langchain_openai import ChatOpenAI

llm = ChatOpenAI(
    model="gpt-4o-mini",
    api_key="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"
)

# %%
from langchain_core.runnables import RunnableLambda

# %%
def get_text(documents):
    return "\n\n".join(doc.page_content for doc in documents)

# Create chain
chain = retriever | RunnableLambda(get_text) | llm

# %%
query = "find me the point Power to stop and search conveyance"

response = chain.invoke(query)

print(response.content)
# Out:
# This text appears to be an excerpt from a legal document, specifically targeting the regulation of narcotic drugs, psychotropic substances, and controlled substances. It outlines the powers of law enforcement in terms of search, arrest, detention, and investigation related to offences under the respective Act. Here's a summary of the key sections highlighted:
#
# ### Chapter III: Search and Investigation
#
# 1. **Power to Issue Warrants (Section 20)**:
#    - A Special Court can issue a warrant for the arrest of individuals suspected of committing offences under the Act or for searching locations believed to contain illicit substances.
#
# 2. **Power of Entry, Search, Seizure, and Arrest Without Warrant (Section 21)**:
# ...
